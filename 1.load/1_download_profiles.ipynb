# %% [markdown]
# ## Load profiles and save it as a parquet file

# %%
import sys

sys.path.append("../scripts")

import pandas as pd

from load import load_config, load_data

# %%
load_orf_data_config = load_config("../configs/load_profiles/all_crispr.yaml")
load_orf_data_config
# Out:
# {'dataset': 'cpg0016-jump', 'source': 'source_13', 'component': 'profiles'}

# %% [markdown]
# ### Load raw profiles
#
# Setting `columns = None` below will load all of the features.
#
# <div class="alert alert-warning">
# WARNING: Files are located in S3. This loop loads only two features per each sampled plate; loading many feature and/or many plates can take several minutes.
# </div>

# %%
profiles = load_data(**load_orf_data_config)

## Example of loading individual batches / plates
# profiles = load(
#     dataset="cpg0016-jump-fixed",
#     source="source_4",
#     component="profiles",
# batch="2021_06_14_Batch6",
# plate="BR00124787",
# columns=["Metadata_Source", "Metadata_Plate", "Metadata_Well", "Cells_AreaShape_Eccentricity", "Nuclei_AreaShape_Area"],
# output="input/raw_profiles_batch6.parquet",
# )
# Out:
# 2023-10-03 14:50:02 INFO     Loading profiles from cellpainting-gallery/cpg0016-jump/source_13/workspace/profiles
# 2023-10-03 14:53:53 INFO     Found 154 files
# 2023-10-03 14:53:53 INFO     Load profiles...

# %%
profiles
# Out:
#       Metadata_Source Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0           source_13   CP-CC9-R1-01           A02           2971.098113
# 1           source_13   CP-CC9-R1-01           A03           2797.762749
# 2           source_13   CP-CC9-R1-01           A04           3516.855417
# 3           source_13   CP-CC9-R1-01           A05           3452.836357
# 4           source_13   CP-CC9-R1-01           A06           3563.686475
# ...               ...            ...           ...                   ...
# 59099       source_13   CP-CC9-R8-02           P20           3103.686916
# 59100       source_13   CP-CC9-R8-02           P21           3280.220845
# 59101       source_13   CP-CC9-R8-02           P22           3174.189162
# 59102       source_13   CP-CC9-R8-02           P23           2704.001277
# 59103       source_13   CP-CC9-R8-02           P24           3468.003563
#
#        Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                          5630.762845                            670.173004
# 1                          5278.723947                            648.544623
# 2                          6751.766173                            660.013250
# 3                          6553.808793                            662.904047
# 4                          6748.133431                            677.737514
# ...                                ...                                   ...
# 59099                      6061.267290                            656.385981
# 59100                      6443.385933                            645.366983
# 59101                      6159.008180                            641.548057
# 59102                      5179.735700                            650.725996
# 59103                      7404.225835                            666.721158
#
#        Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                580.805225
# 1                                586.711752
# 2                                546.800078
# 3                                563.460223
# 4                                553.770324
# ...                                     ...
# 59099                            583.785981
# 59100                            536.537172
# 59101                            553.092706
# 59102                            572.265066
# 59103                            557.095768
#
#        Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                596.549492
# 1                                576.659368
# 2                                579.941543
# 3                                584.155967
# 4                                598.916879
# ...                                     ...
# 59099                            581.508411
# 59100                            567.797376
# 59101                            565.773006
# 59102                            580.696885
# 59103                            583.534967
#
#        Cells_AreaShape_BoundingBoxMinimum_Y  Cells_AreaShape_Center_X  ...  \
# 0                                507.805806                632.822173  ...
# 1                                516.706208                612.173948  ...
# 2                                468.335931                619.504541  ...
# 3                                485.143405                622.956870  ...
# 4                                474.712723                637.807547  ...
# ...                                     ...                       ...  ...
# 59099                            508.837383                618.430717  ...
# 59100                            459.381924                606.146572  ...
# 59101                            477.697342                603.148583  ...
# 59102                            502.879469                615.132620  ...
# 59103                            473.630290                624.792410  ...
#
#        Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                  6.226163
# 1                                  7.107765
# 2                                  8.922541
# 3                                  7.982674
# 4                                 10.368848
# ...                                     ...
# 59099                             12.929285
# 59100                             16.366414
# 59101                             14.140212
# 59102                             11.985358
# 59103                             10.640905
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                  6.449576
# 1                                  7.359348
# 2                                  9.292200
# 3                                  8.243298
# 4                                 10.728938
# ...                                     ...
# 59099                             13.196126
# 59100                             16.565027
# 59101                             14.457187
# 59102                             12.219286
# 59103                             10.913310
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                  6.233986
# 1                                  7.119856
# 2                                  8.964124
# 3                                  7.974916
# 4                                 10.346541
# ...                                     ...
# 59099                             12.944111
# 59100                             16.351609
# 59101                             14.163642
# 59102                             12.006698
# 59103                             10.644751
#
#        Nuclei_Texture_Variance_RNA_5_03_256        dataset        source  \
# 0                                  6.447817  20220914_Run1  CP-CC9-R1-01
# 1                                  7.359909  20220914_Run1  CP-CC9-R1-01
# 2                                  9.255968  20220914_Run1  CP-CC9-R1-01
# 3                                  8.252390  20220914_Run1  CP-CC9-R1-01
# 4                                 10.691082  20220914_Run1  CP-CC9-R1-01
# ...                                     ...            ...           ...
# 59099                             13.201405  20221120_Run6  CP-CC9-R8-02
# 59100                             16.736166  20221120_Run6  CP-CC9-R8-02
# 59101                             14.417285  20221120_Run6  CP-CC9-R8-02
# 59102                             12.178677  20221120_Run6  CP-CC9-R8-02
# 59103                             10.912216  20221120_Run6  CP-CC9-R8-02
#
#        workspace  profiles  batch  plate
# 0           None      None   None   None
# 1           None      None   None   None
# 2           None      None   None   None
# 3           None      None   None   None
# 4           None      None   None   None
# ...          ...       ...    ...    ...
# 59099       None      None   None   None
# 59100       None      None   None   None
# 59101       None      None   None   None
# 59102       None      None   None   None
# 59103       None      None   None   None
#
# [59104 rows x 4771 columns]

# %% [markdown]
# ### Save raw profiles

# %%
profiles.to_parquet("input/raw_profiles.parquet", index=False)
